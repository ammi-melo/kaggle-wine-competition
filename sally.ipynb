# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
Group3= pd.read_csv('Sample_Submission.csv')

# %%
Group3.head()
# Out:
#    id  price
# 0   0     50
# 1   1     50
# 2   2     50
# 3   3     50
# 4   4     50

# %%
Group3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83210 entries, 0 to 83209
# Data columns (total 2 columns):
# id       83210 non-null int64
# price    83210 non-null int64
# dtypes: int64(2)
# memory usage: 1.3 MB

# %%
Group3.describe()
# Out:
#                  id    price
# count  83210.000000  83210.0
# mean   41604.500000     50.0
# std    24020.802287      0.0
# min        0.000000     50.0
# 25%    20802.250000     50.0
# 50%    41604.500000     50.0
# 75%    62406.750000     50.0
# max    83209.000000     50.0

# %%
print(5)
# Out:
# 5
